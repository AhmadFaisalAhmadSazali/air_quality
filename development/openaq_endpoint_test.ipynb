# %%
import os

import httpx
from dotenv import load_dotenv

# %%
load_dotenv()
key = os.getenv("OPENAQ_KEY")
headers = {"X-API-Key":key}

# %%
malaysia_country_url = "https://api.openaq.org/v3/countries/2"

response = httpx.get(malaysia_country_url, headers = headers)
data = response.json()
data
# Out:
# {'meta': {'name': 'openaq-api',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': 1},
#  'results': [{'id': 2,
#    'code': 'MY',
#    'name': 'Malaysia',
#    'datetimeFirst': '2022-11-03T21:00:00Z',
#    'datetimeLast': '2026-01-03T08:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]}]}
